# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# load the file

# %%
df = pd.read_csv("car_prices.csv")
df
# Out:
#                         car_id    price fuel type  gear type           Make  \
# 0     icwAaDOmX573WiRRnLFPT237  2812500    Petrol  Automatic         Toyota
# 1     ByZ3NlPy2x0arAIyrKazClUS  5000000    Petrol  Automatic          Acura
# 2     2zG6Mh3kwyoTvWoeKHkV1oFH  7592000    Petrol  Automatic          Acura
# 3     7APLHOPlI93qsYK0ST4D4wB2  9880000    Petrol  Automatic     Land Rover
# 4      zIrIDPJLd46eRQf9JFacc0e  4160000    Petrol  Automatic           Ford
# ...                        ...      ...       ...        ...            ...
# 3717  C4Ly76wwazrtbYRAWkTnv2Q5  1924000    Petrol  Automatic         Toyota
# 3718  jPA7XlJJxdwpZStlurumw59q  1890000    Petrol  Automatic  Mercedes-Benz
# 3719  g5szhuHeXu2djH1Z2be22G7E  1155000    Petrol  Automatic         Toyota
# 3720  mdZMNQK7Zez0cSS67Q9Quhzr  1260000    Petrol  Automatic         Toyota
# 3721  fSUvulLwnXYlc1muFsrjrsAR  1872000    Petrol  Automatic          Honda
#
# ...

# %% [markdown]
# data description

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3722 entries, 0 to 3721
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_id               3722 non-null   object
#  1   price                3722 non-null   int64
#  2   fuel type            3722 non-null   object
#  3   gear type            3722 non-null   object
#  4   Make                 3722 non-null   object
#  5   Model                3722 non-null   object
#  6   Year of manufacture  3722 non-null   int64
#  7   Colour               3722 non-null   object
#  8   Condition            3722 non-null   object
#  9   Mileage              3722 non-null   int64
#  10  Engine Size          3722 non-null   int64
#  11  Selling Condition    3722 non-null   object
#  12  Bought Condition     3722 non-null   object
#  13  car                  3722 non-null   object
#  14  Registered city      3722 non-null   object
# ...

# %%
df.describe()
# Out:
#               price  Year of manufacture       Mileage   Engine Size
# count  3.722000e+03          3722.000000  3.722000e+03  3.722000e+03
# mean   4.514644e+06          2008.145889  1.946878e+05  1.093999e+04
# std    4.297012e+06             4.205670  1.384842e+05  1.082201e+05
# min    5.500000e+05          1979.000000  1.000000e+00  1.800000e+02
# 25%    2.310000e+06          2005.000000  1.189820e+05  2.000000e+03
# 50%    3.360000e+06          2008.000000  1.762900e+05  2.500000e+03
# 75%    5.036250e+06          2011.000000  2.429852e+05  3.500000e+03
# max    6.240000e+07          2022.000000  2.456318e+06  3.500000e+06

# %% [markdown]
# distribution of car price

# %%
# Plot the distribution of car prices
plt.figure(figsize=(10, 5))
sns.histplot(df['price'], bins=30, kde=True)
plt.title("Distribution of Car Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# most common car brand top 10

# %%
# Count of car brands
top_brands = df['Make'].value_counts().head(10)
top_brands
# Out:
# Make
# Toyota           1598
# Honda             362
# Lexus             350
# Mercedes-Benz     298
# Ford              156
# Hyundai           154
# Nissan            134
# Kia                85
# Acura              81
# Volkswagen         71
# Name: count, dtype: int64

# %% [markdown]
# chart for the most car brands

# %%
# Bar plot of the most common car brands
plt.figure(figsize=(10, 5))
sns.barplot(x=top_brands.index, y=top_brands.values, palette="viridis")
plt.title("Top 10 Most Common Car Brands")
plt.xlabel("Car Brand")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14088\1784276700.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_brands.index, y=top_brands.values, palette="viridis")

# %% [markdown]
# price distribution by fuel type

# %%
# Boxplot of price by fuel type
plt.figure(figsize=(10, 5))
sns.boxplot(x='fuel type', y='price', data=df)
plt.title("Car Prices by Fuel Type")
plt.xlabel("Fuel Type")
plt.ylabel("Price")
plt.show()

# %%
# Scatter plot for Mileage vs Price
plt.figure(figsize=(10, 5))
sns.scatterplot(x=df['Mileage'], y=df['price'], alpha=0.5)
plt.title("Mileage vs Price")
plt.xlabel("Mileage")
plt.ylabel("Price")
plt.show()

# %%
# Average price per year of manufacture
avg_price_per_year = df.groupby("Year of manufacture")["price"].mean()
avg_price_per_year
# Out:
# Year of manufacture
# 1979    1.890000e+06
# 1992    7.350000e+05
# 1994    1.227500e+06
# 1995    1.820625e+06
# 1996    1.365000e+06
# 1997    1.801929e+06
# 1998    1.292167e+06
# 1999    1.510432e+06
# 2000    1.929824e+06
# 2001    1.875810e+06
# 2002    2.106079e+06
# 2003    2.170676e+06
# 2004    2.611207e+06
# 2005    2.812389e+06
# 2006    2.770607e+06
# 2007    3.432722e+06
# 2008    3.603413e+06
# 2009    4.133340e+06
# 2010    4.953721e+06
# 2011    5.553174e+06
# 2012    5.622956e+06
# 2013    6.580019e+06
# 2014    7.754285e+06
# 2015    1.135532e+07
# 2016    1.127031e+07
# 2017    1.260426e+07
# 2018    1.814368e+07
# 2019    1.609245e+07
# 2020    2.487500e+07
# 2021    2.190000e+07
# 2022    1.911000e+07
# Name: price, dtype: float64

# %% [markdown]
# chrt for the average price per year

# %%
# Line plot
plt.figure(figsize=(10, 5))
sns.lineplot(x=avg_price_per_year.index, y=avg_price_per_year.values)
plt.title("Average Car Price by Year of Manufacture")
plt.xlabel("Year")
plt.ylabel("Average Price")
plt.show()

# %% [markdown]
# price by use condition( nigerian use and foreign use)

# %%
# Barplot of price by car condition
plt.figure(figsize=(10, 5))
sns.barplot(x='Condition', y='price', data=df)
plt.title("Car Prices by Condition")
plt.xlabel("Condition")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# top 10 most expensive

# %%
# Display the top 10 most expensive cars
df.nlargest(10, 'price')
# Out:
#                         car_id     price fuel type  gear type           Make  \
# 310   mnaD49ZJjxAqHHlINlIb37vV  62400000    Petrol  Automatic  Mercedes-Benz
# 1667   COKJyH2TZA4xhlALmhYNIR3  61875000    Petrol  Automatic  Mercedes-Benz
# 1877  w1YEI9QoNBnH9RHW9JfK38dm  50400000    Petrol  Automatic     Land Rover
# 2070  CkBL3QDBNkGyHm6kyDhddKzg  50400000    Petrol  Automatic         Toyota
# 1892  mJa0GEXd7edA17Yg5OKnvsVH  49920000    Petrol  Automatic  Mercedes-Benz
# 2270  rapUXgM3qDleAiEEyeLlsC4P  48510000    Petrol  Automatic          Lexus
# 3162  xa1DvNxZRI6RA3SxmNaR9VR8  40950000    Petrol  Automatic          Rover
# 1886   VAtwlX1paMb8YoGLYJczE1O  40250000    Petrol  Automatic  Mercedes-Benz
# 23    iMlUfnetc1gD9gV83W6mX3VI  39900000    Petrol  Automatic     Land Rover
# 1777  iux78BLw6yb4hzXsc4X9fM9c  36170000    Petrol  Automatic           Ford
#
#                   Model  Year of manufacture Colour      Condition  Mileage  \
# ...

# %% [markdown]
# average price by car brand top 10 most expensive

# %%
# Compute average price per car brand
avg_price_brand = df.groupby("Make")["price"].mean().sort_values(ascending=False).head(10)
avg_price_brand
# Out:
# Make
# Bentley          2.415000e+07
# Rover            1.914500e+07
# Land Rover       1.152316e+07
# Jaguar           1.095500e+07
# Porsche          8.610000e+06
# Jeep             7.561083e+06
# Mercedes-Benz    7.546197e+06
# Cadillac         6.693750e+06
# Suzuki           6.300000e+06
# Lexus            5.798240e+06
# Name: price, dtype: float64

# %%
# Bar plot of top 10 most expensive brands on average
plt.figure(figsize=(10, 5))
sns.barplot(x=avg_price_brand.index, y=avg_price_brand.values, palette="coolwarm")
plt.title("Top 10 Most Expensive Car Brands (Average Price)")
plt.xlabel("Car Brand")
plt.ylabel("Average Price")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14088\1987866139.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_price_brand.index, y=avg_price_brand.values, palette="coolwarm")

# %% [markdown]
# top 10 cars with the highest mileage

# %%
# Display the top 10 cars with the highest mileage
df.nlargest(10, 'Mileage')
# Out:
#                         car_id    price fuel type  gear type    Make    Model  \
# 1136  1wGMmybMoppdT6fosFkqUBdU  2288000    Petrol  Automatic  Toyota  Corolla
# 1150  1wGMmybMoppdT6fosFkqUBdU  2288000    Petrol  Automatic  Toyota  Corolla
# 1618  eNF4OA12UIlTk6u2dbqa6Jpo   840000    Petrol  Automatic  Toyota  Corolla
# 42    7PJ6niJkTiX41ci5DiRtjg8o  8320000    Petrol  Automatic  Toyota    Venza
# 1968  gijz8qTR4ERT1Q2uyAaz97fX  4680000    Petrol  Automatic   Lexus       RX
# 1190  BwYKydM2J1JrNRA2qj68X4Ez  1352000    Petrol  Automatic  Toyota    Camry
# 3622   9znJy8msdwlk9lF4bBRkMIr  3150000    Petrol  Automatic   Honda  Odyssey
# 392   dDz4OOAw1xZG3KnM7xMcmZLu  7875000    Petrol  Automatic  Toyota    Venza
# 422   dDz4OOAw1xZG3KnM7xMcmZLu  7875000    Petrol  Automatic  Toyota    Venza
# 1513  dDz4OOAw1xZG3KnM7xMcmZLu  7875000    Petrol  Automatic  Toyota    Venza
#
#       Year of manufacture  Colour      Condition  Mileage  Engine Size  \
# ...

# %%
# Count of cars by year
year_counts = df["Year of manufacture"].value_counts().sort_index()
year_counts
# Out:
# Year of manufacture
# 1979      2
# 1992      1
# 1994      3
# 1995      8
# 1996      7
# 1997     14
# 1998     21
# 1999     22
# 2000     55
# 2001     62
# 2002     98
# 2003    166
# 2004    210
# 2005    266
# 2006    254
# 2007    471
# 2008    411
# 2009    301
# 2010    303
# 2011    235
# 2012    262
# 2013    184
# 2014    144
# 2015     84
# 2016     54
# 2017     27
# 2018     28
# 2019     20
# 2020      7
# 2021      1
# 2022      1
# Name: count, dtype: int64

# %%
# Line plot of car count per year
plt.figure(figsize=(10, 5))
sns.lineplot(x=year_counts.index, y=year_counts.values, marker="o")
plt.title("Number of Cars by Year of Manufacture")
plt.xlabel("Year")
plt.ylabel("Number of Cars")
plt.show()

# %% [markdown]
# price analysis by Gear type

# %%
# Barplot of price distribution by gear type
plt.figure(figsize=(10, 5))
sns.barplot(x="gear type", y="price", data=df)
plt.title("Car Prices by Gear Type")
plt.xlabel("Gear Type")
plt.ylabel("Price")
plt.show()

# %%
#most commom car colour top 10
color_counts = df["Colour"].value_counts().head(10)
color_counts
# Out:
# Colour
# Black     1009
# Gray       668
# Silver     571
# Blue       405
# White      295
# Red        256
# Gold       206
# Green      135
# Brown       90
# Beige       22
# Name: count, dtype: int64

# %%
# Bar plot of top 10 colors
plt.figure(figsize=(10, 5))
sns.barplot(x=color_counts.index, y=color_counts.values, palette="Set2")
plt.title("Top 10 Most Common Car Colors")
plt.xlabel("Color")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14088\2658250889.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=color_counts.index, y=color_counts.values, palette="Set2")

# %%
# Barplot comparing price of "Nigerian Used" vs "Foreign Used"
plt.figure(figsize=(10, 5))
sns.barplot(x="Bought Condition", y="price", data=df)
plt.title("Car Prices by Bought Condition (Nigerian vs Imported)")
plt.xlabel("Bought Condition")
plt.ylabel("Price")
plt.show()
